# %% [markdown]
# <font color='red'> <b> Task Level: INTERMEDIATE </font><br>
# <font color='red'> <b> Task No: 3 </font>

# %% [markdown]
# <font color="green"><b> Project name : Prediction using Decision Tree  Algorithm  </font> <br>
# <font color="blue"> Name : Muzamil amin</font><br>
# <font color="blue"> Language : Python </font><br>

# %% [markdown]
#     Dataset  : https://drive.google.com/file/d/11Iq7YvbWZbt8VXjfm06brx66b10YiwK-/view

# %% [markdown]
# # <b>Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import sklearn.metrics as sm
import seaborn as sns
import matplotlib.pyplot as mt
# %matplotlib inline

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.tree import plot_tree
from sklearn.metrics import accuracy_score
from matplotlib.pyplot import rcParams


import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # <b> Dataset Reading

# %%
dat = pd.read_csv('Iris.csv')
dat
# Out:
#       Id  SepalLengthCm  ...  PetalWidthCm         Species
# 0      1            5.1  ...           0.2     Iris-setosa
# 1      2            4.9  ...           0.2     Iris-setosa
# 2      3            4.7  ...           0.2     Iris-setosa
# 3      4            4.6  ...           0.2     Iris-setosa
# 4      5            5.0  ...           0.2     Iris-setosa
# ..   ...            ...  ...           ...             ...
# 145  146            6.7  ...           2.3  Iris-virginica
# 146  147            6.3  ...           1.9  Iris-virginica
# 147  148            6.5  ...           2.0  Iris-virginica
# 148  149            6.2  ...           2.3  Iris-virginica
# 149  150            5.9  ...           1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
dat.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # <b> Checking Null Values

# %%
dat.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
dat.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %% [markdown]
# # <b>Data Visualization and Correlation Matrix
#
# ---

# %%
sns.pairplot(dat, hue='Species')

# %%
sns.heatmap(dat.corr(),annot=True)

# %% [markdown]
# # <b> Data Preprocessing

# %%
X=dat.iloc[:,[0,1,2,3]]
y=dat.Species
y
dat.shape
# Out:
# (150, 6)

# %%
X.shape
# Out:
# (150, 4)

# %%
y.shape
# Out:
# (150,)

# %% [markdown]
# # <b> Train, Test, Split the Data

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.shape
# Out:
# (105, 4)

# %%
X_test.shape
# Out:
# (45, 4)

# %% [markdown]
# ## <b>Decision Tree

# %%
clf = DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred_train = clf.predict(X_train)
y_pred_test = clf.predict(X_test)

# %%
pd.DataFrame(dat.Species).value_counts()
# Out:
# Species
# Iris-virginica     50
# Iris-versicolor    50
# Iris-setosa        50
# dtype: int64

# %%
accuracy_score(y_train, y_pred_train)
# Out:
# 1.0

# %%
accuracy_score(y_test, y_pred_test)
# Out:
# 1.0

# %%
rcParams['figure.figsize'] = 100, 50
plot_tree(clf,precision=5,rounded=True,filled=True);
